# %%
import numpy as np

# %%
#create a 1-D  array with the size of 5 elements
a1=np.array([940,80,90,30,25,78,78,90,65,54,890,87])
print(a1)
# Out:
# [940  80  90  30  25  78  78  90  65  54 890  87]

# %%
a2=np.copy(a1)
print(a2)
# Out:
# [940  80  90  30  25  78  78  90  65  54 890  87]

# %%
a1[0]=500
print(a1)
print(a2)
# Out:
# [500  80  90  30  25  78  78  90  65  54 890  87]
# [940  80  90  30  25  78  78  90  65  54 890  87]

# %%
a3=a2.view()   
print(a3)
# Out:
# [940  80  90  30  25  78  78  90  65  54 890  87]

# %%
a2[9::]=0   
print(a2)
print(a3)
# Out:
# [940  80  90  30  25  78  78  90  65   0   0   0]
# [940  80  90  30  25  78  78  90  65   0   0   0]

# %%
print(a1)
# Out:
# [500  80  90  30  25  78  78  90  65  54 890  87]

# %%
a1.shape    #we using factors
# Out:
# (12,)

# %%
np.reshape(a1,(2,6))
# Out:
# array([[500,  80,  90,  30,  25,  78],
#        [ 78,  90,  65,  54, 890,  87]])

# %%
np.reshape(a1,(3,4))  # it convertion one dimention to any dimention,vewing in view and it is flexible
# Out:
# array([[500,  80,  90,  30],
#        [ 25,  78,  78,  90],
#        [ 65,  54, 890,  87]])

# %%
np.reshape(a1,(4,3))
# Out:
# array([[500,  80,  90],
#        [ 30,  25,  78],
#        [ 78,  90,  65],
#        [ 54, 890,  87]])

# %%
np.reshape(a1,(6,2))
# Out:
# array([[500,  80],
#        [ 90,  30],
#        [ 25,  78],
#        [ 78,  90],
#        [ 65,  54],
#        [890,  87]])

# %%
np.reshape(a1,(3,2,2))
# Out:
# array([[[500,  80],
#         [ 90,  30]],
#
#        [[ 25,  78],
#         [ 78,  90]],
#
#        [[ 65,  54],
#         [890,  87]]])

# %%
r1=np.reshape(a1,(2,3,2,1))
print(r1)
# Out:
# [[[[500]
#    [ 80]]
#
#   [[ 90]
#    [ 30]]
#
#   [[ 25]
#    [ 78]]]
#
#
#  [[[ 78]
#    [ 90]]
#
#   [[ 65]
#    [ 54]]
#
#   [[890]
#    [ 87]]]]

# %%
np.reshape(r1,shape=-1)   #1-D array,#it can covert one dimension to another,it has high flexibility.
# Out:
# array([500,  80,  90,  30,  25,  78,  78,  90,  65,  54, 890,  87])

# %%
r1=np.reshape(a1,(2,3,2))
print(r1)
# Out:
# [[[500  80]
#   [ 90  30]
#   [ 25  78]]
#
#  [[ 78  90]
#   [ 65  54]
#   [890  87]]]

# %%
r2=np.reshape(r1,shape=-1)
print(r2)
#r2 is a view of r1
# Out:
# [500  80  90  30  25  78  78  90  65  54 890  87]

# %%
r1[1,2,1]
r1[-1,-1,-1]
# Out:
# np.int64(87)

# %%
r1[-1,-1,-1]=999
print(r1,end='\n\n\n')
print(r2)
# Out:
# [[[500  80]
#   [ 90  30]
#   [ 25  78]]
#
#  [[ 78  90]
#   [ 65  54]
#   [890 999]]]
#
#
# [500  80  90  30  25  78  78  90  65  54 890 999]
